# %%
import pandas as pd

# %%
df = pd.read_csv('downloads/HistoricalQuotes.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')  # 👈 important

# %%
df_2019 = df[df['Date'].dt.year == 2019]

# %%
len(df_2019)
# Out:
# 252

# %%
df_2019.head(252)
# Out:
#           Date  Close/Last    Volume      Open        High         Low
# 40  2019-12-31     $293.65  25247630   $289.93     $293.68     $289.52
# 41  2019-12-30     $291.52  36059610   $289.46     $292.69     $285.22
# 42  2019-12-27      $289.8  36592940   $291.12     $293.97     $288.12
# 43  2019-12-26     $289.91  23334000   $284.82     $289.98      $284.7
# 44  2019-12-24     $284.27  12119710   $284.69     $284.89   $282.9197
# ..         ...         ...       ...       ...         ...         ...
# 287 2019-01-08     $150.75  40622910   $149.56     $151.82     $148.52
# 288 2019-01-07     $147.93  54571440    $148.7     $148.83      $145.9
# 289 2019-01-04     $148.26  57423650   $144.53   $148.5499      $143.8
# 290 2019-01-03     $142.19  91106840   $143.98     $145.72        $142
# 291 2019-01-02     $157.92  35637070   $154.89     $158.85     $154.23
#
# [252 rows x 6 columns]
